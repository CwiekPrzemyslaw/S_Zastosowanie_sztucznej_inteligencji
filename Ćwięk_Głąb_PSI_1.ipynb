# %% [markdown]
# ### 1. Wczytanie bibliotek, danych i opis data frame'u

# %% [markdown]
# #### 1.1. Biblioteki

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_absolute_error,root_mean_squared_error, mean_squared_error, r2_score, accuracy_score, classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# #### 1.2. Wczytanie danych

# %%
df = pd.read_csv('adult.data', sep=',', skipinitialspace=True)

# %%
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   50  Self-emp-not-inc   83311  Bachelors             13
# 1   38           Private  215646    HS-grad              9
# 2   53           Private  234721       11th              7
# 3   28           Private  338409  Bachelors             13
# 4   37           Private  284582    Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              13  United-States  <=50K
# 1             0             0              40  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40           Cuba  <=50K
# 4             0             0              40  United-States  <=50K

# %% [markdown]
# #### 1.3. Opis DF

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %% [markdown]
# ### 2. Przygotowanie danych

# %% [markdown]
# #### 2.1. Usunięcie niepotrzebnych kolumn

# %% [markdown]
# - fnlwgt: Ponieważ nie jest potrzebna w analizie ani modelowaniu, ponieważ reprezentuje wagę próby (nie wnosi dodatkowych informacji na temat relacji między predyktorami a zmienną docelową).
# - education: Istnieje już kolumna education-num
# - relationship: Zbędna, mniej istotna niż martial_status
# - capital_gain i capital_loss: Zbędna w kontekście analizy zysków zawodowych

# %%
df = df[['age', 'workclass', 'education_num','marital_status', 'occupation', 'race', 'sex', 'hours_per_week', 'native_country', 'income']]
df.head()
# Out:
#    age         workclass  education_num      marital_status  \
# 0   50  Self-emp-not-inc             13  Married-civ-spouse
# 1   38           Private              9            Divorced
# 2   53           Private              7  Married-civ-spouse
# 3   28           Private             13  Married-civ-spouse
# 4   37           Private             14  Married-civ-spouse
#
#           occupation   race     sex  hours_per_week native_country income
# 0    Exec-managerial  White    Male              13  United-States  <=50K
# 1  Handlers-cleaners  White    Male              40  United-States  <=50K
# 2  Handlers-cleaners  Black    Male              40  United-States  <=50K
# 3     Prof-specialty  Black  Female              40           Cuba  <=50K
# 4    Exec-managerial  White  Female              40  United-States  <=50K

# %% [markdown]
# #### 2.2. Obsługa brakujących danych

# %%
df.isin(['?']).sum() # Braki znajdują się w kolumnach workclass, occupation i native_country. Native_country mogą tak pozostać ponieważ i tak później
# są pogrupowane jako other
# Out:
# age                  0
# workclass         1836
# education_num        0
# marital_status       0
# occupation        1843
# race                 0
# sex                  0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1297
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df = df[~df['workclass'].isin(['Without-pay', 'Never-worked'])] # Usunięcie osób nie zarabiających ponieważ nie powinni być brani pod uwagę

df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1297
# Self-emp-inc         1116
# Federal-gov           960
# Name: count, dtype: int64

# %%
df['workclass'].replace('?', 'Other', inplace=True)

df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Other                1836
# State-gov            1297
# Self-emp-inc         1116
# Federal-gov           960
# Name: count, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4098
# Exec-managerial      4066
# Adm-clerical         3766
# Sales                3650
# Other-service        3294
# Machine-op-inspct    2001
# ?                    1836
# Transport-moving     1596
# Handlers-cleaners    1369
# Farming-fishing       988
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df['occupation'].replace('Armed-Forces', '?', inplace=True) # Dodanie armed forces do ? ponieważ jest ich niewiele

df['occupation'].replace('?', 'Other', inplace=True)

df['occupation'].replace(['Protective-serv', 'Priv-house-serv'], 'Other-service', inplace=True) # Połączenie usług

df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4098
# Other-service        4092
# Exec-managerial      4066
# Adm-clerical         3766
# Sales                3650
# Machine-op-inspct    2001
# Other                1845
# Transport-moving     1596
# Handlers-cleaners    1369
# Farming-fishing       988
# Tech-support          928
# Name: count, dtype: int64

# %%
df.isin(['?']).sum()
# Out:
# age                 0
# workclass           0
# education_num       0
# marital_status      0
# occupation          0
# race                0
# sex                 0
# hours_per_week      0
# native_country    583
# income              0
# dtype: int64

# %% [markdown]
# #### 2.3. Przekształcenia

# %%
df['marital_status'].value_counts() # Dużo niepotrzebnych klas
# Out:
# marital_status
# Married-civ-spouse       14967
# Never-married            10673
# Divorced                  4442
# Separated                 1025
# Widowed                    992
# Married-spouse-absent      417
# Married-AF-spouse           23
# Name: count, dtype: int64

# %%
married_status = ['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse']
single_status = ['Never-married', 'Divorced', 'Widowed', 'Separated']

df['marital_status'].replace(married_status, 'Taken', inplace=True)
df['marital_status'].replace(single_status, 'Single', inplace=True)
df['marital_status'].value_counts() # Zamiana statusów na singla i w związku w celu zmniejszenia ilości kolumn
# Out:
# marital_status
# Single    17132
# Taken     15407
# Name: count, dtype: int64

# %%
df['native_country'].value_counts() # Dużo niepotrzebnych klas
# Out:
# native_country
# United-States                 29149
# Mexico                          643
# ?                               583
# Philippines                     197
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64

# %%
df['native_country'] = np.where(df['native_country'].isin(['United-States']),
                                 df['native_country'],
                                 'Other')  # Podział na mieszkańców i obcokrajowców 

df['native_country'].value_counts()
# Out:
# native_country
# United-States    29149
# Other             3390
# Name: count, dtype: int64

# %%
df['race'].value_counts()
# Out:
# race
# White                 27798
# Black                  3121
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
other_races = ['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Other'] # Połączenie mniej licznych ras

df['race'].replace(other_races, 'Other', inplace=True)

df['race'].value_counts()
# Out:
# race
# White    27798
# Black     3121
# Other     1620
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['income'], drop_first=True) # Zamiana na bool większe/równe 50k = True

df = pd.get_dummies(df, columns=['sex'], drop_first=True) # Zamiana na bool mężczyzna = True

df = pd.get_dummies(df, columns=['workclass','marital_status', 'occupation', 'race', 'native_country']) # one hot encoding

df.head()
# Out:
#    age  education_num  hours_per_week  income_>50K  sex_Male  \
# 0   50             13              13        False      True
# 1   38              9              40        False      True
# 2   53              7              40        False      True
# 3   28             13              40        False     False
# 4   37             14              40        False     False
#
#    workclass_Federal-gov  workclass_Local-gov  workclass_Other  \
# 0                  False                False            False
# 1                  False                False            False
# 2                  False                False            False
# 3                  False                False            False
# 4                  False                False            False
#
#    workclass_Private  workclass_Self-emp-inc  ...  occupation_Other-service  \
# 0              False                   False  ...                     False
# 1               True                   False  ...                     False
# 2               True                   False  ...                     False
# 3               True                   False  ...                     False
# 4               True                   False  ...                     False
#
#    occupation_Prof-specialty  occupation_Sales  occupation_Tech-support  \
# 0                      False             False                    False
# 1                      False             False                    False
# 2                      False             False                    False
# 3                       True             False                    False
# 4                      False             False                    False
#
#    occupation_Transport-moving  race_Black  race_Other  race_White  \
# 0                        False       False       False        True
# 1                        False       False       False        True
# 2                        False        True       False       False
# 3                        False        True       False       False
# 4                        False       False       False        True
#
#    native_country_Other  native_country_United-States
# 0                 False                          True
# 1                 False                          True
# 2                 False                          True
# 3                  True                         False
# 4                 False                          True
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 3. Podział na zbiory, trening i ocena

# %%
y = df['income_>50K']
X = df.drop(['income_>50K'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state=42)

# %% [markdown]
# ### 4. Modele

# %% [markdown]
# #### 4.1a Random forest (domyślny)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# %%
conf_matrix_rf = confusion_matrix(y_test, y_pred)
class_report_rf = classification_report(y_test, y_pred)
accuracy_rf = accuracy_score(y_test, y_pred)

print("=== Wyniki Klasyfikacji Random Forest (domyślny) ===")
print("Confusion Matrix:\n", conf_matrix_rf)
print("\nClassification Report:\n", class_report_rf)
print(f"Accuracy: {accuracy_rf}")
# Out:
# === Wyniki Klasyfikacji Random Forest (domyślny) ===
# Confusion Matrix:
#  [[6619  791]
#  [1046 1306]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.86      0.89      0.88      7410
#         True       0.62      0.56      0.59      2352
#
#     accuracy                           0.81      9762
#    macro avg       0.74      0.72      0.73      9762
# weighted avg       0.81      0.81      0.81      9762
#
# Accuracy: 0.811821348084409

# %% [markdown]
# #### 4.1b Random forest (dostrojony)

# %%
rf_params = {'n_estimators': [50, 100, 200], 'max_depth': [10, 20, None], 'min_samples_split': [2, 5, 10]}
rf_grid = GridSearchCV(RandomForestClassifier(), rf_params, scoring='accuracy', cv=3)
rf_grid.fit(X_train, y_train)
rf_best = rf_grid.best_estimator_  
rf_predictions = rf_best.predict(X_test)

# %%
conf_matrix_rf = confusion_matrix(y_test, rf_predictions)
class_report_rf = classification_report(y_test, rf_predictions)
accuracy_rf = accuracy_score(y_test, rf_predictions)

print("=== Wyniki Klasyfikacji Random Forest (dostrojony) ===")
print("Confusion Matrix:\n", conf_matrix_rf)
print("\nClassification Report:\n", class_report_rf)
print(f"Accuracy: {accuracy_rf}")
# Out:
# === Wyniki Klasyfikacji Random Forest (dostrojony) ===
# Confusion Matrix:
#  [[6850  560]
#  [1046 1306]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.87      0.92      0.90      7410
#         True       0.70      0.56      0.62      2352
#
#     accuracy                           0.84      9762
#    macro avg       0.78      0.74      0.76      9762
# weighted avg       0.83      0.84      0.83      9762
#
# Accuracy: 0.8354845318582258

# %% [markdown]
# #### 4.2a Logistic regression (domyślny)

# %%
logistic_model = LogisticRegression(max_iter=1000)
logistic_model.fit(X_train, y_train)
y_pred = logistic_model.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("=== Wyniki Klasyfikacji Logistic Regression (domyślny) ===")
print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
print(f"Accuracy: {accuracy}")
# Out:
# === Wyniki Klasyfikacji Logistic Regression (domyślny) ===
# Confusion Matrix:
#  [[6812  598]
#  [1083 1269]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.86      0.92      0.89      7410
#         True       0.68      0.54      0.60      2352
#
#     accuracy                           0.83      9762
#    macro avg       0.77      0.73      0.75      9762
# weighted avg       0.82      0.83      0.82      9762
#
# Accuracy: 0.8278016799836099

# %% [markdown]
# #### 4.2b Logistic regression (dostrojony)

# %%
lr_params = {'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]}
lr_grid = GridSearchCV(LogisticRegression(max_iter=1000), lr_params, scoring='accuracy', cv=3)
lr_grid.fit(X_train, y_train)
lr_best = lr_grid.best_estimator_
lr_predictions = lr_best.predict(X_test)

# %%
conf_matrix_rf = confusion_matrix(y_test, lr_predictions)
class_report_rf = classification_report(y_test, lr_predictions)
accuracy_rf = accuracy_score(y_test, lr_predictions)

print("=== Wyniki Klasyfikacji Logistic Regression (dostrojony) ===")
print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
print(f"Accuracy: {accuracy}")
# Out:
# === Wyniki Klasyfikacji Logistic Regression (dostrojony) ===
# Confusion Matrix:
#  [[7034  376]
#  [1347 1005]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.84      0.95      0.89      7410
#         True       0.73      0.43      0.54      2352
#
#     accuracy                           0.82      9762
#    macro avg       0.78      0.69      0.71      9762
# weighted avg       0.81      0.82      0.81      9762
#
# Accuracy: 0.823499282933825

# %% [markdown]
# #### 4.3. KNN (domyślny)

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

class_report = classification_report(y_test, y_pred)

accuracy = accuracy_score(y_test, y_pred)

print("=== Wyniki Klasyfikacji KNN (domyślny) ===")
print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
print(f"Accuracy: {accuracy}")
# Out:
# === Wyniki Klasyfikacji KNN (domyślny) ===
# Confusion Matrix:
#  [[6579  831]
#  [1040 1312]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.86      0.89      0.88      7410
#         True       0.61      0.56      0.58      2352
#
#     accuracy                           0.81      9762
#    macro avg       0.74      0.72      0.73      9762
# weighted avg       0.80      0.81      0.81      9762
#
# Accuracy: 0.808338455234583

# %% [markdown]
# #### 4.3. KNN (dostrojony)

# %%
knn_params = {
    'n_neighbors': [1, 3, 5, 7, 9, 11, 15, 20],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}
knn_grid = GridSearchCV(KNeighborsClassifier(), knn_params, scoring='accuracy', cv=3)
knn_grid.fit(X_train, y_train)
knn_best = knn_grid.best_estimator_
knn_predictions = knn_best.predict(X_test)

# %%
conf_matrix_knn = confusion_matrix(y_test, knn_predictions)
class_report_knn = classification_report(y_test, knn_predictions)
accuracy_knn = accuracy_score(y_test, knn_predictions)

print("=== Wyniki Klasyfikacji KNN === (dostrojony)")
print("Confusion Matrix:\n", conf_matrix_knn)
print("\nClassification Report:\n", class_report_knn)
print(f"Accuracy: {accuracy_knn}")
# Out:
# === Wyniki Klasyfikacji KNN === (dostrojony)
# Confusion Matrix:
#  [[6778  632]
#  [1115 1237]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.86      0.91      0.89      7410
#         True       0.66      0.53      0.59      2352
#
#     accuracy                           0.82      9762
#    macro avg       0.76      0.72      0.74      9762
# weighted avg       0.81      0.82      0.81      9762
#
# Accuracy: 0.821040770333948

# %% [markdown]
# #### 4.4. SVM (domyślny)

# %%
model_svc = svm.SVC()

model_svc.fit(X_train, y_train)

y_pred = model_svc.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("=== Wyniki Klasyfikacji CVM === (domyślny)")
print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
print(f"Accuracy: {accuracy}")
# Out:
# === Wyniki Klasyfikacji CVM === (domyślny)
# Confusion Matrix:
#  [[7034  376]
#  [1347 1005]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.84      0.95      0.89      7410
#         True       0.73      0.43      0.54      2352
#
#     accuracy                           0.82      9762
#    macro avg       0.78      0.69      0.71      9762
# weighted avg       0.81      0.82      0.81      9762
#
# Accuracy: 0.823499282933825

# %% [markdown]
# #### 4.4. SVM (dostrojony)

# %%
svm_params = {'C': [0.1, 1, 10]}
svm_grid = GridSearchCV(SVC(), svm_params, scoring='accuracy', cv=3)
svm_grid.fit(X_train, y_train)
svm_best = svm_grid.best_estimator_
svmpredictions = svm_best.predict(X_test)

# %%
conf_matrix_svm = confusion_matrix(y_test, svmpredictions)
class_report_svm = classification_report(y_test, svmpredictions)
accuracy_svm = accuracy_score(y_test, svmpredictions)

print("=== Wyniki Klasyfikacji SVM (dostrojony) ===")
print("Confusion Matrix:\n", conf_matrix_svm)
print("\nClassification Report:\n", class_report_svm)
print(f"Accuracy: {accuracy_svm}")
# Out:
# === Wyniki Klasyfikacji SVM (dostrojony) ===
# Confusion Matrix:
#  [[6965  445]
#  [1182 1170]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.85      0.94      0.90      7410
#         True       0.72      0.50      0.59      2352
#
#     accuracy                           0.83      9762
#    macro avg       0.79      0.72      0.74      9762
# weighted avg       0.82      0.83      0.82      9762
#
# Accuracy: 0.8333333333333334
